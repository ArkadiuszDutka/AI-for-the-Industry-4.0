# %% [markdown]
# **Import of necessary Python libraries**
#
# ---

# %%
import numpy as np
import pandas as pd
from google.colab import files
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression

# %% [markdown]
# **Loading data from my Google Drive**
#
# ---

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
with open('/content/drive/My Drive/sensor01_air.txt', 'r') as file:
  air01 = file.read()
with open('/content/drive/My Drive/sensor02_air.txt', 'r') as file:
  air02 = file.read()  
with open('/content/drive/My Drive/sensor03_air.txt', 'r') as file:
  air03 = file.read()
with open('/content/drive/My Drive/sensor04_air.txt', 'r') as file:
  air04 = file.read()  
with open('/content/drive/My Drive/sensor05_air.txt', 'r') as file:
  air05 = file.read()    
with open('/content/drive/My Drive/sensor06_air.txt', 'r') as file:
  air06 = file.read()     
with open('/content/drive/My Drive/sensor07_air.txt', 'r') as file:
  air07 = file.read()
with open('/content/drive/My Drive/sensor08_air.txt', 'r') as file:
  air08 = file.read() 
with open('/content/drive/My Drive/sensor09_air.txt', 'r') as file:
  air09 = file.read() 
with open('/content/drive/My Drive/sensor10_air.txt', 'r') as file:
  air10 = file.read()

# %%
with open('/content/drive/My Drive/sensor01_izopropanol.txt', 'r') as file:
  izopropanol01 = file.read()
with open('/content/drive/My Drive/sensor02_izopropanol.txt', 'r') as file:
  izopropanol02 = file.read()
with open('/content/drive/My Drive/sensor03_izopropanol.txt', 'r') as file:
  izopropanol03 = file.read()
with open('/content/drive/My Drive/sensor04_izopropanol.txt', 'r') as file:
  izopropanol04 = file.read()  
with open('/content/drive/My Drive/sensor05_izopropanol.txt', 'r') as file:
  izopropanol05 = file.read()  
with open('/content/drive/My Drive/sensor06_izopropanol.txt', 'r') as file:
  izopropanol06 = file.read()    
with open('/content/drive/My Drive/sensor07_izopropanol.txt', 'r') as file:
  izopropanol07 = file.read() 
with open('/content/drive/My Drive/sensor08_izopropanol.txt', 'r') as file:
  izopropanol08 = file.read() 
with open('/content/drive/My Drive/sensor09_izopropanol.txt', 'r') as file:
  izopropanol09 = file.read() 
with open('/content/drive/My Drive/sensor10_izopropanol.txt', 'r') as file:
  izopropanol10 = file.read()

# %%
with open('/content/drive/My Drive/sensor01_water.txt', 'r') as file:
  water01 = file.read()
with open('/content/drive/My Drive/sensor02_water.txt', 'r') as file:
  water02 = file.read()  
with open('/content/drive/My Drive/sensor03_water.txt', 'r') as file:
  water03 = file.read()
with open('/content/drive/My Drive/sensor04_water.txt', 'r') as file:
  water04 = file.read()  
with open('/content/drive/My Drive/sensor05_water.txt', 'r') as file:
  water05 = file.read() 
with open('/content/drive/My Drive/sensor06_water.txt', 'r') as file:
  water06 = file.read() 
with open('/content/drive/My Drive/sensor07_water.txt', 'r') as file:
  water07 = file.read()
with open('/content/drive/My Drive/sensor08_water.txt', 'r') as file:
  water08 = file.read()
with open('/content/drive/My Drive/sensor09_water.txt', 'r') as file:
  water09 = file.read()
with open('/content/drive/My Drive/sensor10_water.txt', 'r') as file:
  water10 = file.read()

# %% [markdown]
# **Printing part of the data from first three datasets**
#
# ---

# %%
data1 = np.loadtxt('/content/drive/My Drive/sensor01_air.txt', delimiter=',')
print(data1[:10])
# Out:
# [[1.3500e-06 9.1792e+00]
#  [1.3501e-06 9.2003e+00]
#  [1.3502e-06 9.1968e+00]
#  [1.3503e-06 9.1028e+00]
#  [1.3504e-06 9.0601e+00]
#  [1.3505e-06 9.1118e+00]
#  [1.3506e-06 9.1082e+00]
#  [1.3507e-06 9.1401e+00]
#  [1.3508e-06 9.2533e+00]
#  [1.3509e-06 9.1403e+00]]

# %%
data2 = np.loadtxt('/content/drive/My Drive/sensor01_izopropanol.txt', delimiter=',')
print(data2[:10])
# Out:
# [[1.3500e-06 8.5551e+00]
#  [1.3501e-06 8.6750e+00]
#  [1.3502e-06 8.7116e+00]
#  [1.3503e-06 8.7157e+00]
#  [1.3504e-06 8.6792e+00]
#  [1.3505e-06 8.6312e+00]
#  [1.3506e-06 8.5790e+00]
#  [1.3507e-06 8.7378e+00]
#  [1.3508e-06 8.7874e+00]
#  [1.3509e-06 8.5679e+00]]

# %%
data3 = np.loadtxt('/content/drive/My Drive/sensor01_water.txt', delimiter=',')
print(data3[:10])
# Out:
# [[1.3500e-06 8.3570e+00]
#  [1.3501e-06 8.4287e+00]
#  [1.3502e-06 8.4422e+00]
#  [1.3503e-06 8.4144e+00]
#  [1.3504e-06 8.4034e+00]
#  [1.3505e-06 8.3351e+00]
#  [1.3506e-06 8.2999e+00]
#  [1.3507e-06 8.4229e+00]
#  [1.3508e-06 8.5613e+00]
#  [1.3509e-06 8.4437e+00]]

# %%
# Read the contents of the file into a pandas DataFrame
df_air01 = pd.read_csv('/content/drive/My Drive/sensor01_air.txt', header=None, names=['Time_air01', 'Value_air01'])
df_izopropanol01 = pd.read_csv('/content/drive/My Drive/sensor01_izopropanol.txt', header=None, names=['Time_izopropanol01', 'Value_izopropanol01'])
df_water01 = pd.read_csv('/content/drive/My Drive/sensor01_water.txt', header=None, names=['Time_water01', 'Value_water01'])


# Print the DataFrame
print(df_air01)
print(df_izopropanol01)
print(df_water01)
# Out:
#       Time_air01  Value_air01
# 0       0.000001       9.1792
# 1       0.000001       9.2003
# 2       0.000001       9.1968
# 3       0.000001       9.1028
# 4       0.000001       9.0601
# ...          ...          ...
# 2996    0.000002       3.8310
# 2997    0.000002       3.8613
# 2998    0.000002       3.8361
# 2999    0.000002       3.9466
# 3000    0.000002       3.8974
#
# [3001 rows x 2 columns]
#       Time_izopropanol01  Value_izopropanol01
# 0               0.000001             8.555100
# 1               0.000001             8.675000
# 2               0.000001             8.711600
# 3               0.000001             8.715700
# 4               0.000001             8.679200
# ...                  ...                  ...
# 2996            0.000002            -0.335950
# 2997            0.000002            -0.199560
# 2998            0.000002            -0.403730
# 2999            0.000002             0.028674
# 3000            0.000002            -0.221990
#
# ...

# %% [markdown]
# **Displaying data from first two datasets in a plot**
#
# ---

# %%
df_air01 = pd.read_csv('/content/drive/My Drive/sensor01_air.txt', header=None, names=['Time_air01', 'Value_air01'])

# Read the contents of the second file into a pandas DataFrame
df_izopropanol01 = pd.read_csv('/content/drive/My Drive/sensor01_izopropanol.txt', header=None, names=['Time_izopropanol01', 'Value_izopropanol01'])

df_water01 = pd.read_csv('/content/drive/My Drive/sensor01_water.txt', header=None, names=['Time_water01', 'Value_water01'])

# Create a line plot of the 'Value' column for both data series
plt.plot(df_air01['Value_air01'], label='Air01')
plt.plot(df_izopropanol01['Value_izopropanol01'], label='Izopropanol01')
plt.plot(df_water01['Value_water01'], label='Water01')


# Add a legend to the plot
plt.legend()

# Add axis labels and a title to the plot
plt.xlabel('λ [nm]')
plt.ylabel('P\Pref [dB]')
plt.title('1st Sample')

# Display the plot
plt.show()

# %%
df_air01 = pd.read_csv('/content/drive/My Drive/sensor02_air.txt', header=None, names=['Time_air02', 'Value_air02'])

# Read the contents of the second file into a pandas DataFrame
df_izopropanol01 = pd.read_csv('/content/drive/My Drive/sensor02_izopropanol.txt', header=None, names=['Time_izopropanol02', 'Value_izopropanol02'])

df_water01 = pd.read_csv('/content/drive/My Drive/sensor02_water.txt', header=None, names=['Time_water02', 'Value_water02'])

# Create a line plot of the 'Value' column for both data series
plt.plot(df_air01['Value_air02'], label='Air')
plt.plot(df_izopropanol01['Value_izopropanol02'], label='Izopropanol')
plt.plot(df_water01['Value_water02'], label='Water')


# Add a legend to the plot
plt.legend()

# Add axis labels and a title to the plot
plt.xlabel('λ [nm]')
plt.ylabel('P\Pref [dB]')
plt.title('2nd Sample')

# Display the plot
plt.show()

# %% [markdown]
# **Displaying data from all collections divided into categories**
#
# ---

# %%
df_air01 = pd.read_csv('/content/drive/My Drive/sensor01_air.txt', header=None, names=['Time_air01', 'Value_air01'])
df_air02 = pd.read_csv('/content/drive/My Drive/sensor02_air.txt', header=None, names=['Time_air02', 'Value_air02'])
df_air03 = pd.read_csv('/content/drive/My Drive/sensor03_air.txt', header=None, names=['Time_air03', 'Value_air03'])
df_air04 = pd.read_csv('/content/drive/My Drive/sensor04_air.txt', header=None, names=['Time_air04', 'Value_air04'])
df_air05 = pd.read_csv('/content/drive/My Drive/sensor05_air.txt', header=None, names=['Time_air05', 'Value_air05'])
df_air06 = pd.read_csv('/content/drive/My Drive/sensor06_air.txt', header=None, names=['Time_air06', 'Value_air06'])
df_air07 = pd.read_csv('/content/drive/My Drive/sensor07_air.txt', header=None, names=['Time_air07', 'Value_air07'])
df_air08 = pd.read_csv('/content/drive/My Drive/sensor08_air.txt', header=None, names=['Time_air08', 'Value_air08'])
df_air09 = pd.read_csv('/content/drive/My Drive/sensor09_air.txt', header=None, names=['Time_air09', 'Value_air09'])
df_air10 = pd.read_csv('/content/drive/My Drive/sensor10_air.txt', header=None, names=['Time_air10', 'Value_air10'])

plt.figure(figsize=(10, 6))  # Set the size of the plot

# Create a line plot of the 'Value' column for both data series
plt.plot(df_air01['Value_air01'], label='Air01')
plt.plot(df_air02['Value_air02'], label='Air02')
plt.plot(df_air03['Value_air03'], label='Air03')
plt.plot(df_air04['Value_air04'], label='Air04')
plt.plot(df_air05['Value_air05'], label='Air05')
plt.plot(df_air06['Value_air06'], label='Air06')
plt.plot(df_air07['Value_air07'], label='Air07')
plt.plot(df_air08['Value_air08'], label='Air08')
plt.plot(df_air09['Value_air09'], label='Air09')
plt.plot(df_air10['Value_air10'], label='Air10')

# Add a legend to the plot
plt.legend()

# Add axis labels and a title to the plot
plt.xlabel('λ [nm]')
plt.ylabel('P\Pref [dB]')
plt.title('Air Values')

# Display the plot
plt.show()

# %%
df_izopropanol01 = pd.read_csv('/content/drive/My Drive/sensor01_izopropanol.txt', header=None, names=['Time_izopropanol01', 'Value_izopropanol01'])
df_izopropanol02 = pd.read_csv('/content/drive/My Drive/sensor02_izopropanol.txt', header=None, names=['Time_izopropanol02', 'Value_izopropanol02'])
df_izopropanol03 = pd.read_csv('/content/drive/My Drive/sensor03_izopropanol.txt', header=None, names=['Time_izopropanol03', 'Value_izopropanol03'])
df_izopropanol04 = pd.read_csv('/content/drive/My Drive/sensor04_izopropanol.txt', header=None, names=['Time_izopropanol04', 'Value_izopropanol04'])
df_izopropanol05 = pd.read_csv('/content/drive/My Drive/sensor05_izopropanol.txt', header=None, names=['Time_izopropanol05', 'Value_izopropanol05'])
df_izopropanol06 = pd.read_csv('/content/drive/My Drive/sensor06_izopropanol.txt', header=None, names=['Time_izopropanol06', 'Value_izopropanol06'])
df_izopropanol07 = pd.read_csv('/content/drive/My Drive/sensor07_izopropanol.txt', header=None, names=['Time_izopropanol07', 'Value_izopropanol07'])
df_izopropanol08 = pd.read_csv('/content/drive/My Drive/sensor08_izopropanol.txt', header=None, names=['Time_izopropanol08', 'Value_izopropanol08'])
df_izopropanol09 = pd.read_csv('/content/drive/My Drive/sensor09_izopropanol.txt', header=None, names=['Time_izopropanol09', 'Value_izopropanol09'])
df_izopropanol10 = pd.read_csv('/content/drive/My Drive/sensor10_izopropanol.txt', header=None, names=['Time_izopropanol10', 'Value_izopropanol10'])

plt.figure(figsize=(10, 6))  # Set the size of the plot

# Create a line plot of the 'Value' column for both data series
plt.plot(df_izopropanol01['Value_izopropanol01'], label='Izopropanol01')
plt.plot(df_izopropanol02['Value_izopropanol02'], label='Izopropanol02')
plt.plot(df_izopropanol03['Value_izopropanol03'], label='Izopropanol03')
plt.plot(df_izopropanol04['Value_izopropanol04'], label='Izopropanol04')
plt.plot(df_izopropanol05['Value_izopropanol05'], label='Izopropanol05')
plt.plot(df_izopropanol06['Value_izopropanol06'], label='Izopropanol06')
plt.plot(df_izopropanol07['Value_izopropanol07'], label='Izopropanol07')
plt.plot(df_izopropanol08['Value_izopropanol08'], label='Izopropanol08')
plt.plot(df_izopropanol09['Value_izopropanol09'], label='Izopropanol09')
plt.plot(df_izopropanol10['Value_izopropanol10'], label='Izopropanol10')

# Add a legend to the plot
plt.legend()

# Add axis labels and a title to the plot
plt.xlabel('λ [nm]')
plt.ylabel('P\Pref [dB]')
plt.title('Izopropanol values')

# Display the plot
plt.show()

# %%
df_water01 = pd.read_csv('/content/drive/My Drive/sensor01_water.txt', header=None, names=['Time_water01', 'Value_water01'])
df_water02 = pd.read_csv('/content/drive/My Drive/sensor02_water.txt', header=None, names=['Time_water02', 'Value_water02'])
df_water03 = pd.read_csv('/content/drive/My Drive/sensor03_water.txt', header=None, names=['Time_water03', 'Value_water03'])
df_water04 = pd.read_csv('/content/drive/My Drive/sensor04_water.txt', header=None, names=['Time_water04', 'Value_water04'])
df_water05 = pd.read_csv('/content/drive/My Drive/sensor05_water.txt', header=None, names=['Time_water05', 'Value_water05'])
df_water06 = pd.read_csv('/content/drive/My Drive/sensor06_water.txt', header=None, names=['Time_water06', 'Value_water06'])
df_water07 = pd.read_csv('/content/drive/My Drive/sensor07_water.txt', header=None, names=['Time_water07', 'Value_water07'])
df_water08 = pd.read_csv('/content/drive/My Drive/sensor08_water.txt', header=None, names=['Time_water08', 'Value_water08'])
df_water09 = pd.read_csv('/content/drive/My Drive/sensor09_water.txt', header=None, names=['Time_water09', 'Value_water09'])
df_water10 = pd.read_csv('/content/drive/My Drive/sensor10_water.txt', header=None, names=['Time_water10', 'Value_water10'])

plt.figure(figsize=(10, 6))  # Set the size of the plot

# Create a line plot of the 'Value' column for both data series
plt.plot(df_water01['Value_water01'], label='Water01')
plt.plot(df_water02['Value_water02'], label='Water02')
plt.plot(df_water03['Value_water03'], label='Water03')
plt.plot(df_water04['Value_water04'], label='Water04')
plt.plot(df_water05['Value_water05'], label='Water05')
plt.plot(df_water06['Value_water06'], label='Water06')
plt.plot(df_water07['Value_water07'], label='Water07')
plt.plot(df_water08['Value_water08'], label='Water08')
plt.plot(df_water09['Value_water09'], label='Water09')
plt.plot(df_water10['Value_water10'], label='Water10')

# Add a legend to the plot
plt.legend()

# Add axis labels and a title to the plot
plt.xlabel('λ [nm]')
plt.ylabel('P\Pref [dB]')
plt.title('Water values')

# Display the plot
plt.show()

# %%
data_air01 = np.loadtxt("/content/drive/My Drive/sensor01_air.txt", delimiter=",", skiprows=1)
data_izopropanol01 = np.loadtxt("/content/drive/My Drive/sensor01_izopropanol.txt", delimiter=",", skiprows=1)
data_water01 = np.loadtxt("/content/drive/My Drive/sensor01_water.txt", delimiter=",", skiprows=1)

# Get time and signal values
time_air01 = data_air01[:, 0]
signal_air01 = data_air01[:, 1]
time_izopropanol01 = data_izopropanol01[:, 0]
signal_izopropanol01 = data_izopropanol01[:, 1]
time_water01 = data_water01[:, 0]
signal_water01 = data_water01[:, 1]

# Perform FFT
freq_air01 = np.fft.fftfreq(signal_air01.size, d=time_air01[1]-time_air01[0])
fft_air01 = np.fft.fft(signal_air01)
freq_izopropanol01 = np.fft.fftfreq(signal_izopropanol01.size, d=time_izopropanol01[1]-time_izopropanol01[0])
fft_izopropanol01 = np.fft.fft(signal_izopropanol01)
freq_water01 = np.fft.fftfreq(signal_water01.size, d=time_water01[1]-time_water01[0])
fft_water01 = np.fft.fft(signal_water01)

# Plot FFT
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.subplot(131)
plt.plot(freq_air01, np.abs(fft_air01))
plt.title("FFT - Air01")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Amplitude")
plt.subplot(132)
plt.plot(freq_izopropanol01, np.abs(fft_izopropanol01))
plt.title("FFT - Izopropanol01")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Amplitude")
plt.subplot(133)
plt.plot(freq_water01, np.abs(fft_water01))
plt.title("FFT - Water01")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Amplitude")
plt.show()

# %% [markdown]
# **Performing a Fast Fourier Transform (FFT) and obtaining a representation of the signals in the frequency domain**
#
# ---

# %%
air_data = pd.read_csv('/content/drive/My Drive/sensor01_air.txt', sep='\t', header=None, names=['Time_air01', 'Value_air01'])
izopropanol_data = pd.read_csv('/content/drive/My Drive/sensor01_izopropanol.txt', sep='\t', header=None, names=['Time_izopropanol01', 'Value_izopropanol01'])
water_data = pd.read_csv('/content/drive/My Drive/sensor01_water.txt', sep='\t', header=None, names=['Time_water01', 'Value_water01'])

# %%
time_air01 = air_data['Time_air01']
signal_air01 = air_data['Value_air01']
time_izopropanol01 = izopropanol_data['Time_izopropanol01']
signal_izopropanol01 = izopropanol_data['Value_izopropanol01']
time_water01 = water_data['Time_water01']
signal_water01 = water_data['Value_water01']

# %%
# Load data
data_air01 = np.loadtxt('/content/drive/My Drive/sensor01_air.txt', delimiter=',', skiprows=1)
data_izopropanol01 = np.loadtxt('/content/drive/My Drive/sensor01_izopropanol.txt', delimiter=',', skiprows=1)
data_water01 = np.loadtxt('/content/drive/My Drive/sensor01_water.txt', delimiter=',', skiprows=1)

# Get time and signal values
time_air01 = data_air01[:, 0]
signal_air01 = data_air01[:, 1]
time_izopropanol01 = data_izopropanol01[:, 0]
signal_izopropanol01 = data_izopropanol01[:, 1]
time_water01 = data_water01[:, 0]
signal_water01 = data_water01[:, 1]

# Perform linear regression
from sklearn.linear_model import LinearRegression

model_air01 = LinearRegression().fit(time_air01.reshape(-1, 1), signal_air01.reshape(-1, 1))
model_izopropanol01 = LinearRegression().fit(time_izopropanol01.reshape(-1, 1), signal_izopropanol01.reshape(-1, 1))
model_water01 = LinearRegression().fit(time_water01.reshape(-1, 1), signal_water01.reshape(-1, 1))

# Get regression coefficients
coeffs_air01 = model_air01.coef_[0][0]
intercept_air01 = model_air01.intercept_[0]
coeffs_izopropanol01 = model_izopropanol01.coef_[0][0]
intercept_izopropanol01 = model_izopropanol01.intercept_[0]
coeffs_water01 = model_water01.coef_[0][0]
intercept_water01 = model_water01.intercept_[0]

# Print regression coefficients
print("Air01 - Coeffs: {}, Intercept: {}".format(coeffs_air01, intercept_air01))
print("Izopropanol01 - Coeffs: {}, Intercept: {}".format(coeffs_izopropanol01, intercept_izopropanol01))
print("Water01 - Coeffs: {}, Intercept: {}".format(coeffs_water01, intercept_water01))
# Out:
# Air01 - Coeffs: -29047843.301679876, Intercept: 44.76093054995823
# Izopropanol01 - Coeffs: -57415694.42878628, Intercept: 84.60399769060085
# Water01 - Coeffs: -54931472.04773289, Intercept: 80.99538676073504

# %%
# Load data
data_air02 = np.loadtxt('/content/drive/My Drive/sensor02_air.txt', delimiter=',', skiprows=1)
data_izopropanol02 = np.loadtxt('/content/drive/My Drive/sensor02_izopropanol.txt', delimiter=',', skiprows=1)
data_water02 = np.loadtxt('/content/drive/My Drive/sensor02_water.txt', delimiter=',', skiprows=1)

# Get time and signal values
time_air02 = data_air02[:, 0]
signal_air02 = data_air02[:, 1]
time_izopropanol02 = data_izopropanol02[:, 0]
signal_izopropanol02 = data_izopropanol02[:, 1]
time_water02 = data_water02[:, 0]
signal_water02 = data_water02[:, 1]

# Perform linear regression
from sklearn.linear_model import LinearRegression

model_air02 = LinearRegression().fit(time_air02.reshape(-1, 1), signal_air02.reshape(-1, 1))
model_izopropanol02 = LinearRegression().fit(time_izopropanol01.reshape(-1, 1), signal_izopropanol02.reshape(-1, 1))
model_water02 = LinearRegression().fit(time_water02.reshape(-1, 1), signal_water02.reshape(-1, 1))

# Get regression coefficients
coeffs_air02 = model_air02.coef_[0][0]
intercept_air02 = model_air02.intercept_[0]
coeffs_izopropanol02 = model_izopropanol02.coef_[0][0]
intercept_izopropanol02 = model_izopropanol02.intercept_[0]
coeffs_water02 = model_water02.coef_[0][0]
intercept_water02 = model_water02.intercept_[0]

# Print regression coefficients
print("Air02 - Coeffs: {}, Intercept: {}".format(coeffs_air01, intercept_air01))
print("Izopropanol02 - Coeffs: {}, Intercept: {}".format(coeffs_izopropanol01, intercept_izopropanol01))
print("Water02 - Coeffs: {}, Intercept: {}".format(coeffs_water01, intercept_water01))
# Out:
# Air02 - Coeffs: -29047843.301679876, Intercept: 44.76093054995823
# Izopropanol02 - Coeffs: -57415694.42878628, Intercept: 84.60399769060085
# Water02 - Coeffs: -54931472.04773289, Intercept: 80.99538676073504

# %%
# Load data
data_air03 = np.loadtxt('/content/drive/My Drive/sensor03_air.txt', delimiter=',', skiprows=1)
data_izopropanol03 = np.loadtxt('/content/drive/My Drive/sensor03_izopropanol.txt', delimiter=',', skiprows=1)
data_water03 = np.loadtxt('/content/drive/My Drive/sensor03_water.txt', delimiter=',', skiprows=1)

# Get time and signal values
time_air03 = data_air03[:, 0]
signal_air03 = data_air03[:, 1]
time_izopropanol03 = data_izopropanol03[:, 0]
signal_izopropanol03 = data_izopropanol03[:, 1]
time_water03 = data_water03[:, 0]
signal_water03 = data_water03[:, 1]

# Perform linear regression
from sklearn.linear_model import LinearRegression

model_air03 = LinearRegression().fit(time_air03.reshape(-1, 1), signal_air03.reshape(-1, 1))
model_izopropanol03 = LinearRegression().fit(time_izopropanol03.reshape(-1, 1), signal_izopropanol03.reshape(-1, 1))
model_water03 = LinearRegression().fit(time_water03.reshape(-1, 1), signal_water03.reshape(-1, 1))

# Get regression coefficients
coeffs_air03 = model_air03.coef_[0][0]
intercept_air03 = model_air03.intercept_[0]
coeffs_izopropanol03 = model_izopropanol03.coef_[0][0]
intercept_izopropanol03 = model_izopropanol03.intercept_[0]
coeffs_water03 = model_water03.coef_[0][0]
intercept_water03 = model_water03.intercept_[0]

# Print regression coefficients
print("Air02 - Coeffs: {}, Intercept: {}".format(coeffs_air01, intercept_air01))
print("Izopropanol02 - Coeffs: {}, Intercept: {}".format(coeffs_izopropanol01, intercept_izopropanol01))
print("Water02 - Coeffs: {}, Intercept: {}".format(coeffs_water01, intercept_water01))
# Out:
# Air02 - Coeffs: -29047843.301679876, Intercept: 44.76093054995823
# Izopropanol02 - Coeffs: -57415694.42878628, Intercept: 84.60399769060085
# Water02 - Coeffs: -54931472.04773289, Intercept: 80.99538676073504
